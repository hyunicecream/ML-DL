# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunicecream/ML-DL/blob/main/%08KMeans%20Elbow%20Method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Elbow 방법으로 최적 cluster 개수를 찾는다.
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# 시험용 데이터 셋을 구성한다.
X, y = make_blobs(n_samples=150,
                  n_features=2,
                  centers=3,
                  cluster_std=0.5,
                  shuffle=True,
                  random_state=0)

# %%
# 엘보우 (elbow) 방법으로 최적 cluster 개수를 찾아본다. 
distortions = []
for i in range(2, 11):
    km = KMeans(n_clusters=i,
                init='random',
                n_init=100,
                max_iter=300,
                tol=1e-04,
                random_state=0)
    km = km.fit(X)
    # Cluster내의 SSE를 계산한다.
    # 관성 (inertia), 혹은 왜곡 (distortion)이라고도 한다.
    distortions.append(km.inertia_)

# %%
# 시각화 하기
plt.plot(range(2, 11), distortions, marker='o') 
plt.xlabel('Number of clusters') 
plt.ylabel('Distortion')
plt.show()

# %% [markdown]
# ![스크린샷 2022-01-27 오후 12.49.30.png](data:image/png;base64,...)
